# %% [markdown]
# Я провел A/B тест для проверки гипотезы о том, что баннер с яркой желтой картинкой будет работать лучше, чем минималистичный баннер с нейтральной картинкой

# %% [markdown]
# # Баннер №1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#   # Баннер №2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Тест проводился на платформе VK рекламы и проводилась рекламная компания моего паблика в VK "Стажер Тинькофф" https://vk.com/intern_tinkoff

# %% [markdown]
# Группы пользователей были равны и каждый из баннеров посмотрело 3500 человек, при этом на первый баннер кликнуло 18 человек, а на второй 9

# %% [markdown]
# Нужно узнать является ли этот результат статистически значимым, я принял уровень значимости равным a = 0.05

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Таким образом результат является статистически значимым и первая гипотеза отвергается, а альтернативная (минималистичный баннер работает лучше) принимается
